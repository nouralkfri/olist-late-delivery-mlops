# %%
import pandas as pd
train = pd.read_parquet('train.parquet')
train.info()
train.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61744 entries, 0 to 61743
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       61744 non-null  str
#  1   customer_id                    61744 non-null  str
#  2   order_status                   61744 non-null  str
#  3   order_purchase_timestamp       61744 non-null  str
#  4   order_approved_at              61734 non-null  str
#  5   order_delivered_carrier_date   61743 non-null  str
#  6   order_delivered_customer_date  61744 non-null  datetime64[us]
#  7   order_estimated_delivery_date  61744 non-null  datetime64[us]
#  8   customer_unique_id             61744 non-null  str
#  9   customer_zip_code_prefix       61744 non-null  int64
#  10  customer_city                  61744 non-null  str
#  11  customer_state                 61744 non-null  str
# ...

# %%
train.isna().sum().sort_values(ascending=False).head(10)
# Out:
# order_approved_at                10
# order_delivered_carrier_date      1
# n_payments                        1
# total_payment                     1
# customer_id                       0
# order_id                          0
# order_delivered_customer_date     0
# order_estimated_delivery_date     0
# order_purchase_timestamp          0
# order_status                      0
# dtype: int64

# %%
train.groupby('is_late')[['total_price', 'total_freight', 'n_items']].mean()
# Out:
#          total_price  total_freight   n_items
# is_late
# 0         136.233623      22.647663  1.143230
# 1         146.897279      24.635914  1.109581

# %%
train.to_parquet('train_eda.parquet', index=False)  
print("saved!")
# Out:
# saved!
